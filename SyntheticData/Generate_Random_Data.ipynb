# %% [markdown]
# <a href="https://colab.research.google.com/github/mspendyala/data-engineering/blob/main/SyntheticData/Generate_Random_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://pythonsimplified.com/generate-fake-data-using-faker-and-python/

# %%
pip install faker-credit-score
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for faker-credit-score: filename=faker_credit_score-0.3.0-py3-none-any.whl size=4217 sha256=5236988131f88fb642b591a5be59f3fe4917fcd1ecb4feb6d99e16b95196d231
#   Stored in directory: /root/.cache/pip/wheels/f5/7e/e5/542ce70c5cc10c1062535a205315dccc6c30805e7af2e86fd8
# Successfully built faker-credit-score
# ...

# %%
import pandas as pd
from faker import Faker
from faker_credit_score import CreditScore
Faker.seed(42)

fake = Faker(locale='en_US')
fake.add_provider(CreditScore)

fake_credit_cards = [
    {'first_name': fake.first_name(),
     'last_name': fake.last_name(),
     'address': fake.address(),
     'cred_card_provider': fake.credit_card_provider(),
     'credit_card_number': fake.credit_card_number(),
     'credit_card_expire': fake.credit_card_expire(),
     'credit_card_score': fake.credit_score(),
     'credit_card_score_provider': fake.credit_score_provider(),
     'credit_card_security_code': fake.credit_card_security_code()}
    for x in range(100)]

df = pd.DataFrame(fake_credit_cards)

# %%
df
# Out:
#    first_name  last_name                                            address  \
# 0    Danielle    Johnson         18196 Anthony Forge\nNew Carolyn, ID 94351
# 1      Amanda     Dudley  959 Janet Cape Apt. 413\nSouth Joshuastad, MN ...
# 2       Diana     Foster                   PSC 7242, Box 3884\nAPO AP 77123
# 3       Kayla   Peterson        0482 Monica Hills\nEast Nathaniel, ND 70015
# 4      Rodney      Lewis       465 Lam Mission\nEast Jeffreymouth, OR 73104
# ..        ...        ...                                                ...
# 95     Joseph   Williams       5561 Melissa Cape\nPort Devonburgh, MI 57873
# 96   Samantha  Rodriguez         45089 Tiffany Skyway\nAprilville, TN 95744
# 97    William     Pierce              77971 West Crest\nMcgeetown, MO 54547
# 98   Jennifer     Wilson            55488 Park Cape\nSouth Donald, WA 95077
# 99   Savannah   Roberson              922 Paul Rapid\nWilliamfurt, PA 91270
#
# ...
